# %%
from my_experiment import Experiment

# %% [markdown]
# Experiments for the best combinations while using the best performing z and k improvements

# %%
k=[5,6,7,8,9,10,13,17,21,30,40]

# %% [markdown]
# Bottom 25% of k values AND middle z values with half accuracy

# %%
z1 = list(d for d in range(4, 8))
k1 = k[:int(len(k)*0.25)]
speedups, f1s = Experiment.test_all_datasets(mode='both', slide=100, window=200, k=k1, z=z1)
Experiment.plot_results(speedups, f1s, title='Bottom 25% of k values AND middle z values with half accuracy')
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 36.85it/s]
# 100%|██████████| 100/100 [00:03<00:00, 26.99it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.46it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.10it/s]
# [0.19189029070592956, 0.37168322971430817, 0.3661319531388491, 0.3034936171948319] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.010345151589065404, 0.012017507983087539, -0.0013405023129667848, -0.00980407867792854]

# %% [markdown]
# Middle k values with half accuracy AND middle half of z values

# %%
k2 = k[::2]
z2 = list(d/2 for d in range(8, 16))
speedups, f1s = Experiment.test_all_datasets(mode='both', slide=100, window=200, k=k2, z=z2)
Experiment.plot_results(speedups, f1s, title='Every second k value AND middle half z values')
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 24.82it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.90it/s]
# 100%|██████████| 100/100 [00:06<00:00, 14.89it/s]
# 100%|██████████| 100/100 [00:06<00:00, 14.80it/s]
# [0.18558390619745035, 0.39093890277045357, 0.37835751435662324, 0.31464200559288324] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.004038767080586203, 0.03127318103923293, 0.010885058904807343, 0.0013443097201227827]

# %% [markdown]
# Middle k values with half accuracy AND middle z values with half accuracy

# %%
k_temp = k[int(len(k)*0.25):int(len(k)*0.75)]
k3 = k_temp[::2]
z3 = list(d for d in range(4, 8))
speedups, f1s = Experiment.test_all_datasets(mode='both', slide=100, window=200, k=k3, z=z3)
Experiment.plot_results(speedups, f1s, title='Middle k values with half accuracy AND middle z values with half accuracy')
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 34.39it/s]
# 100%|██████████| 100/100 [00:03<00:00, 26.01it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.02it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.81it/s]
# [0.19354748608754152, 0.3845939783999406, 0.36155218521988636, 0.2953669173140924] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.012002346970677369, 0.02492825666871995, -0.005920270231929536, -0.017930778558668037]
