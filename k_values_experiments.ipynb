# %%
from my_experiment import Experiment

# %% [markdown]
# Original k neighbors tested --> 5,6,7,8,9,10,13,17,21,30,40

# %%
k=[5,6,7,8,9,10,13,17,21,30,40]

# %% [markdown]
# Half accuracy of k

# %%
k1 = k[::2]
speedups, f1s = Experiment.test_all_datasets(mode='k', slide=100, window=200, k=k1)
Experiment.plot_results(speedups, f1s, title='Half accuracy of k values')
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 23.60it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.15it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.69it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.54it/s]
# [0.19474845452770642, 0.32258815479302955, 0.3657435064803759, 0.29653400467928936] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.01320331541084227, -0.03707756693819109, -0.001728948971439992, -0.016763691193471097]

# %% [markdown]
# Bottom 75% of k values

# %%
k2 = k[:int(len(k)*0.75)]
speedups, f1s = Experiment.test_all_datasets(mode='k', slide=100, window=200, k=k2)
Experiment.plot_results(speedups, f1s, title='Bottom 75% of k values')
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.55it/s]
# 100%|██████████| 100/100 [00:06<00:00, 14.37it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.90it/s]
# 100%|██████████| 100/100 [00:09<00:00, 11.10it/s]
# [0.19296676945815883, 0.32611011276407126, 0.360629519189596, 0.2958599042921132] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.011421630341294675, -0.033555608967149375, -0.006842936262219879, -0.01743779158064729]

# %% [markdown]
# Bottom 50% of k values

# %%
k3 = k[:int(len(k)*0.5)]
speedups, f1s = Experiment.test_all_datasets(mode='k', slide=100, window=200, k=k3)
Experiment.plot_results(speedups, f1s, title='Bottom 50% of k values')
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 24.43it/s]
# 100%|██████████| 100/100 [00:05<00:00, 17.87it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.63it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.15it/s]
# [0.19296913014045788, 0.3241197918491803, 0.36133555192968636, 0.2960547370890769] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.011423991023593733, -0.035545929882040306, -0.006136903522129533, -0.017242958783683537]

# %% [markdown]
# Bottom 25% of k values

# %%
k4 = k[:int(len(k)*0.25)]
speedups, f1s = Experiment.test_all_datasets(mode='k', slide=100, window=200, k=k4)
Experiment.plot_results(speedups, f1s, title='Bottom 25% of k values')
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 32.32it/s]
# 100%|██████████| 100/100 [00:04<00:00, 22.92it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.21it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.76it/s]
# [0.19277236988198643, 0.3258114087612317, 0.35995887211254507, 0.2962484733570727] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.011227230765122276, -0.03385431296998892, -0.007513583339270824, -0.017049222515687745]

# %% [markdown]
# Middle 50% of k values

# %%
# Middle 50% of k values
k5 = k[int(len(k)*0.25):int(len(k)*0.75)]
speedups, f1s = Experiment.test_all_datasets(mode='k', slide=100, window=200, k=k5)
Experiment.plot_results(speedups, f1s, title='Middle 50% of k values')
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 22.42it/s]
# 100%|██████████| 100/100 [00:05<00:00, 16.75it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.68it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.53it/s]
# [0.2057301105531892, 0.33892397737596636, 0.3737575377321723, 0.3047996891934368] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.02418497143632506, -0.020741744355254277, 0.006285082280356402, -0.008498006679323655]

# %%
k5
# Out:
# [7, 8, 9, 10, 13, 17]

# %% [markdown]
# Half accuracy of middle 50%

# %%
k6 = k5[::2]
speedups, f1s = Experiment.test_all_datasets(mode='k', slide=100, window=200, k=k6)
Experiment.plot_results(speedups, f1s, title='Half accuracy of middle 50% of k values')
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 29.04it/s]
# 100%|██████████| 100/100 [00:04<00:00, 20.59it/s]
# 100%|██████████| 100/100 [00:06<00:00, 16.43it/s]
# 100%|██████████| 100/100 [00:06<00:00, 16.60it/s]
# [0.20597348948749367, 0.3397561579733484, 0.37189102070519253, 0.30542338765636295] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.024428350370629515, -0.01990956375787223, 0.004418565253376638, -0.007874308216397508]

# %%
k6
# Out:
# [7, 9, 13]
