# %%
from my_experiment import Experiment

# %% [markdown]
# Original z values --> 2, 2.5, 3, ..., 9.5, 10

# %% [markdown]
# Bottom 75% of original z values 2, 2.5, ..., 7.5, 8

# %%
z1 = list(d / 2 for d in range(4, 16))
speedups, f1s = Experiment.test_all_datasets(mode='z', slide=100, window=200, z=z1)
Experiment.plot_results(speedups, f1s, title='Bottom 75% of z values')
# Out:
# ...
# 100%|██████████| 100/100 [00:11<00:00,  8.43it/s]
# [0.1831261981454079, 0.3574546530551281, 0.37401117165515724, 0.31662596081094013] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.0015810590285437465, -0.0022110686760925535, 0.006538716203341344, 0.0033282649381796703]

# %% [markdown]
# Bottom Half z values

# %%
z2 = list(d / 2 for d in range(4, 12))
speedups, f1s = Experiment.test_all_datasets(mode='z', slide=100, window=200, z=z2)
Experiment.plot_results(speedups, f1s, title='Bottom 50% of z values')
# Out:
# ...
# 100%|██████████| 100/100 [00:11<00:00,  8.74it/s]
# [0.19296676945815883, 0.3223598087058345, 0.360629519189596, 0.2958599042921132] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.011421630341294675, -0.037305913025386106, -0.006842936262219879, -0.01743779158064729]

# %% [markdown]
# Bottom 25% of original z values

# %%
z3 = list(d / 2 for d in range(4, 8))
speedups, f1s = Experiment.test_all_datasets(mode='z', slide=100, window=200, z=z3)
Experiment.plot_results(speedups, f1s, title='Bottom 25% of z values')
# Out:
# ...
# 100%|██████████| 100/100 [00:07<00:00, 12.66it/s]
# [0.209088291466222, 0.22489312322235352, 0.26604150927911707, 0.2080783437308186] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.027543152349357836, -0.1347725985088671, -0.10143094617269882, -0.10521935214194186]

# %% [markdown]
# Half Accuracy of original z values (δεν παίρνω τις .5 τιμές)

# %%
z4 = list(d for d in range(2, 10))
speedups, f1s = Experiment.test_all_datasets(mode='z', slide=100, window=200, z=z4)
Experiment.plot_results(speedups, f1s, title='Half accuracy of z values')
# Out:
# ...
# 100%|██████████| 100/100 [00:09<00:00, 10.81it/s]
# [0.17773826855256822, 0.3258410576750439, 0.35135342818960424, 0.3010207027843189] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [-0.0038068705642959333, -0.033824664056176734, -0.01611902726221165, -0.012276993088441546]

# %% [markdown]
# Middle half of z values

# %%
z5 = list(d/2 for d in range(8, 16))
speedups, f1s = Experiment.test_all_datasets(mode='z', slide=100, window=200, z=z5)
Experiment.plot_results(speedups, f1s, title='Middle half of z values')
# Out:
# ...
# 100%|██████████| 100/100 [00:08<00:00, 11.35it/s]
# [0.1847702340420601, 0.38931963506761497, 0.37431179695578254, 0.31662596081094013] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.0032250949251959593, 0.029653913336394333, 0.006839341503966645, 0.0033282649381796703]

# %% [markdown]
# Middle half, half accuracy

# %%
z6 = list(d for d in range(4, 8))
speedups, f1s = Experiment.test_all_datasets(mode='z', slide=100, window=200, z=z6)
Experiment.plot_results(speedups, f1s, title='Half accuracy of middle half of z values')
# Out:
# ...
# 100%|██████████| 100/100 [00:06<00:00, 14.51it/s]
# [0.19337961762323053, 0.3674914011431804, 0.3626248084000852, 0.30478913558118875] [0.18154513911686415, 0.35966572173122063, 0.3674724554518159, 0.31329769587276046]
# [0.011834478506366375, 0.007825679411959774, -0.004847647051730686, -0.00850856029157171]
